# %%
# !nvidia-smi
# Out:
# Fri Mar 13 07:53:18 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-80GB          Off |   00000000:00:05.0 Off |                    0 |
# | N/A   35C    P0             56W /  400W |       0MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !rm -rf /content/emg2qwerty
# !GIT_LFS_SKIP_SMUDGE=1 git clone https://github.com/jacekasen/ece-c147a-project.git /content/emg2qwerty
# !cd /content/emg2qwerty && pip install -r requirements.txt -q && pip install -e . -q
# Out:
# Cloning into '/content/emg2qwerty'...
# remote: Enumerating objects: 183, done.
# remote: Counting objects: 100% (183/183), done.
# remote: Compressing objects: 100% (131/131), done.
# remote: Total 183 (delta 61), reused 168 (delta 46), pack-reused 0 (from 0)
# Receiving objects: 100% (183/183), 33.53 MiB | 18.74 MiB/s, done.
# Resolving deltas: 100% (61/61), done.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 553.6/553.6 kB 29.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 7.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 12.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.1/542.1 kB 44.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 137.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 19.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 437.2/437.2 kB 46.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.8/300.8 kB 35.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.6/163.6 kB 19.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 104.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 123.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 104.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.3/204.3 kB 26.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.3/325.3 kB 35.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.3/800.3 kB 68.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.1/779.1 MB 1.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.2/38.2 MB 69.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 894.6/894.6 kB 69.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 127.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 155.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 kB 56.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 461.6/461.6 kB 46.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 28.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 128.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 99.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 69.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 23.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 44.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 20.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 11.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.3/153.3 kB 19.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.1/254.1 kB 29.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.7/40.7 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.0/172.0 kB 20.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.4/99.4 kB 12.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 141.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 9.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 12.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 147.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 50.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 123.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 7.4 MB/s eta 0:00:00
#   Building wheel for kenlm (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# access 1.1.10.post3 requires scipy>=1.14.1, but you have scipy 1.13.1 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# tsfresh 0.21.1 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# typer-slim 0.24.0 requires typer>=0.24.0, but you have typer 0.23.1 which is incompatible.
# textblob 0.19.0 requires nltk>=3.9, but you have nltk 3.8.1 which is incompatible.
# google-adk 1.26.0 requires click<9.0.0,>=8.1.8, but you have click 8.1.7 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.4 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.3.1 which is incompatible.
# tobler 0.13.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
#   Preparing metadata (setup.py) ... done

# %%
# --- CONFIG ---
DATA   = "/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/data/89335547"
LOGS   = "/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs"
REPO   = "/content/emg2qwerty"

MODEL = "transformer_ctc"
EXP   = "transformer_run1"

# %% [markdown]
# ## Train

# %%
# !cd {REPO} && python -m emg2qwerty.train \
  user="single_user" \
  model={MODEL} \
  dataset.root="{DATA}" \
  hydra.run.dir="{LOGS}/{EXP}" \
  trainer.accelerator=gpu trainer.devices=1 \
  trainer.max_epochs=40
# Out:
# [2026-03-13 07:57:38,352][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622679967-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-03-1622764398-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626917264-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622889105-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-03-1622766673-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622861066-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627001995-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622884635-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626915176-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   val:
#   - user: 89335547
#     session: 2021-06-04-1622862148-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   test:
#   - user: 89335547
#     session: 2021-06-02-1622682789-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   root: /content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/data/89335547
# to_tensor:
#   _target_: emg2qwerty.transforms.ToTensor
#   fields:
#   - emg_left
#   - emg_right
# band_rotation:
#   _target_: emg2qwerty.transforms.ForEach
#   transform:
#     _target_: emg2qwerty.transforms.RandomBandRotation
#     offsets:
#     - -1
#     - 0
#     - 1
# temporal_jitter:
#   _target_: emg2qwerty.transforms.TemporalAlignmentJitter
#   max_offset: 120
# logspec:
#   _target_: emg2qwerty.transforms.LogSpectrogram
#   n_fft: 64
#   hop_length: 16
# specaug:
#   _target_: emg2qwerty.transforms.SpecAugment
#   n_time_masks: 3
#   time_mask_param: 25
#   n_freq_masks: 2
#   freq_mask_param: 4
# transforms:
#   train:
#   - ${to_tensor}
#   - ${band_rotation}
#   - ${temporal_jitter}
#   - ${logspec}
#   - ${specaug}
#   val:
#   - ${to_tensor}
#   - ${logspec}
#   test: ${transforms.val}
# module:
#   _target_: emg2qwerty.lightning.TransformerCTCModule
#   in_features: 528
#   mlp_features:
#   - 384
#   d_model: 256
#   nhead: 8
#   num_layers: 4
#   dim_feedforward: 1024
#   dropout: 0.1
# datamodule:
#   _target_: emg2qwerty.lightning.WindowedEMGDataModule
#   window_length: 8000
#   padding:
#   - 1800
#   - 200
# optimizer:
#   _target_: torch.optim.Adam
#   lr: 0.001
# lr_scheduler:
#   scheduler:
#     _target_: pl_bolts.optimizers.lr_scheduler.LinearWarmupCosineAnnealingLR
#     warmup_epochs: 10
#     max_epochs: ${trainer.max_epochs}
#     warmup_start_lr: 1.0e-08
#     eta_min: 1.0e-06
#   interval: epoch
# decoder:
#   _target_: emg2qwerty.decoder.CTCGreedyDecoder
# seed: 1501
# batch_size: 32
# num_workers: 4
# train: true
# checkpoint: null
# monitor_metric: val/CER
# monitor_mode: min
# trainer:
#   accelerator: gpu
#   devices: 1
#   num_nodes: 1
#   max_epochs: 40
#   default_root_dir: ${hydra:runtime.output_dir}
# callbacks:
# - _target_: pytorch_lightning.callbacks.LearningRateMonitor
# - _target_: pytorch_lightning.callbacks.ModelCheckpoint
#   dirpath: ${hydra:runtime.output_dir}/checkpoints
#   monitor: ${monitor_metric}
#   mode: ${monitor_mode}
#   save_last: true
#   verbose: true
#
# Global seed set to 1501
# [2026-03-13 07:57:38,355][__main__][INFO] - Instantiating LightningModule {'_target_': 'emg2qwerty.lightning.TransformerCTCModule', 'in_features': 528, 'mlp_features': [384], 'd_model': 256, 'nhead': 8, 'num_layers': 4, 'dim_feedforward': 1024, 'dropout': 0.1}
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [2026-03-13 07:57:38,454][__main__][INFO] - Instantiating LightningDataModule {'_target_': 'emg2qwerty.lightning.WindowedEMGDataModule', 'window_length': 8000, 'padding': [1800, 200]}
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: /content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/lightning_logs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.12/dist-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# /usr/local/lib/python3.12/dist-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/matplotlib/_fontconfig_pattern.py:64: PyparsingDeprecationWarning: 'oneOf' deprecated - use 'one_of'
#   prop = Group((name + Suppress("=") + comma_separated(value)) | oneOf(_CONSTANTS))
# /usr/local/lib/python3.12/dist-packages/matplotlib/_fontconfig_pattern.py:85: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   parse = parser.parseString(pattern)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_fontconfig_pattern.py:89: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   parser.resetCache()
# /usr/local/lib/python3.12/dist-packages/pl_bolts/models/self_supervised/amdim/amdim_module.py:34: UnderReviewWarning: The feature generate_power_seq is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   "lr_options": generate_power_seq(LEARNING_RATE_CIFAR, 11),
# /usr/local/lib/python3.12/dist-packages/pl_bolts/models/self_supervised/amdim/amdim_module.py:92: UnderReviewWarning: The feature FeatureMapContrastiveTask is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   contrastive_task: Union[FeatureMapContrastiveTask] = FeatureMapContrastiveTask("01, 02, 11"),
# /usr/local/lib/python3.12/dist-packages/pl_bolts/losses/self_supervised_learning.py:228: UnderReviewWarning: The feature AmdimNCELoss is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   self.nce_loss = AmdimNCELoss(tclip)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:45: PyparsingDeprecationWarning: 'enablePackrat' deprecated - use 'enable_packrat'
#   ParserElement.enablePackrat()
# [2026-03-13 07:58:17,367][matplotlib.style.core][WARNING] - In /usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle: 'parseString' deprecated - use 'parse_string'
# [2026-03-13 07:58:17,367][matplotlib.style.core][WARNING] - In /usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle: 'resetCache' deprecated - use 'reset_cache'
# /usr/local/lib/python3.12/dist-packages/hydra/_internal/instantiate/_instantiate2.py:92: UnderReviewWarning: The feature LinearWarmupCosineAnnealingLR is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   return _target_(*args, **kwargs)
#
#   | Name     | Type       | Params
# ----------------------------------------
# 0 | model    | Sequential | 3.8 M
# 1 | ctc_loss | CTCLoss    | 0
# 2 | metrics  | ModuleDict | 0
# ----------------------------------------
# 3.8 M     Trainable params
# 0         Non-trainable params
# 3.8 M     Total params
# 15.151    Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]/usr/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=2332) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# Epoch 0:  94% 120/127 [00:54<00:03,  2.20it/s, loss=155, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 0: 100% 127/127 [00:56<00:00,  2.26it/s, loss=155, v_num=0]
# Epoch 0: 100% 127/127 [00:56<00:00,  2.26it/s, loss=155, v_num=0]Epoch 0, global step 120: 'val/CER' reached 622.99512 (best 622.99512), saving model to '/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/epoch=0-step=120.ckpt' as top 1
# Epoch 1:  94% 120/127 [00:25<00:01,  4.80it/s, loss=3.74, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 1: 100% 127/127 [00:26<00:00,  4.78it/s, loss=3.74, v_num=0]
# Epoch 1: 100% 127/127 [00:26<00:00,  4.78it/s, loss=3.74, v_num=0]Epoch 1, global step 240: 'val/CER' reached 100.00000 (best 100.00000), saving model to '/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/epoch=1-step=240.ckpt' as top 1
# Epoch 2:  94% 120/127 [00:25<00:01,  4.63it/s, loss=3.54, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 2: 100% 127/127 [00:27<00:00,  4.62it/s, loss=3.54, v_num=0]
# Epoch 2: 100% 127/127 [00:27<00:00,  4.62it/s, loss=3.54, v_num=0]Epoch 2, global step 360: 'val/CER' was not in top 1
# Epoch 3:  94% 120/127 [00:25<00:01,  4.65it/s, loss=3.38, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 3: 100% 127/127 [00:27<00:00,  4.64it/s, loss=3.38, v_num=0]
# Epoch 3: 100% 127/127 [00:27<00:00,  4.64it/s, loss=3.38, v_num=0]Epoch 3, global step 480: 'val/CER' was not in top 1
# Epoch 4:  94% 120/127 [00:24<00:01,  4.84it/s, loss=3.38, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 4: 100% 127/127 [00:26<00:00,  4.83it/s, loss=3.38, v_num=0]
# Epoch 4: 100% 127/127 [00:26<00:00,  4.83it/s, loss=3.38, v_num=0]Epoch 4, global step 600: 'val/CER' was not in top 1
# Epoch 5:  94% 120/127 [00:24<00:01,  4.86it/s, loss=3.28, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 5: 100% 127/127 [00:26<00:00,  4.83it/s, loss=3.28, v_num=0]
# Epoch 5: 100% 127/127 [00:26<00:00,  4.83it/s, loss=3.28, v_num=0]Epoch 5, global step 720: 'val/CER' was not in top 1
# Epoch 6:  94% 120/127 [00:24<00:01,  4.85it/s, loss=3.33, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 6: 100% 127/127 [00:26<00:00,  4.83it/s, loss=3.33, v_num=0]
# Epoch 6: 100% 127/127 [00:26<00:00,  4.83it/s, loss=3.33, v_num=0]Epoch 6, global step 840: 'val/CER' was not in top 1
# Epoch 7:  94% 120/127 [00:25<00:01,  4.79it/s, loss=3.19, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 7: 100% 127/127 [00:26<00:00,  4.78it/s, loss=3.19, v_num=0]
# Epoch 7: 100% 127/127 [00:26<00:00,  4.78it/s, loss=3.19, v_num=0]Epoch 7, global step 960: 'val/CER' was not in top 1
# Epoch 8:  94% 120/127 [00:24<00:01,  4.84it/s, loss=3.19, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 8: 100% 127/127 [00:26<00:00,  4.82it/s, loss=3.19, v_num=0]
# Epoch 8: 100% 127/127 [00:26<00:00,  4.82it/s, loss=3.19, v_num=0]Epoch 8, global step 1080: 'val/CER' was not in top 1
# Epoch 9:  94% 120/127 [00:24<00:01,  4.88it/s, loss=3.16, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 9: 100% 127/127 [00:26<00:00,  4.86it/s, loss=3.16, v_num=0]
# Epoch 9: 100% 127/127 [00:26<00:00,  4.86it/s, loss=3.16, v_num=0]Epoch 9, global step 1200: 'val/CER' was not in top 1
# Epoch 10:  94% 120/127 [00:24<00:01,  4.82it/s, loss=3.08, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 10: 100% 127/127 [00:26<00:00,  4.81it/s, loss=3.08, v_num=0]
# Epoch 10: 100% 127/127 [00:26<00:00,  4.81it/s, loss=3.08, v_num=0]Epoch 10, global step 1320: 'val/CER' was not in top 1
# Epoch 11:  94% 120/127 [00:25<00:01,  4.80it/s, loss=3.01, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 11: 100% 127/127 [00:26<00:00,  4.79it/s, loss=3.01, v_num=0]
# Epoch 11: 100% 127/127 [00:26<00:00,  4.79it/s, loss=3.01, v_num=0]Epoch 11, global step 1440: 'val/CER' was not in top 1
# Epoch 12:  94% 120/127 [00:24<00:01,  4.87it/s, loss=2.96, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 12: 100% 127/127 [00:26<00:00,  4.84it/s, loss=2.96, v_num=0]
# Epoch 12: 100% 127/127 [00:26<00:00,  4.84it/s, loss=2.96, v_num=0]Epoch 12, global step 1560: 'val/CER' was not in top 1
# Epoch 13:  94% 120/127 [00:25<00:01,  4.77it/s, loss=2.98, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 13: 100% 127/127 [00:26<00:00,  4.76it/s, loss=2.98, v_num=0]
# Epoch 13: 100% 127/127 [00:26<00:00,  4.76it/s, loss=2.98, v_num=0]Epoch 13, global step 1680: 'val/CER' was not in top 1
# Epoch 14:  94% 120/127 [00:24<00:01,  4.85it/s, loss=2.9, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 14: 100% 127/127 [00:26<00:00,  4.82it/s, loss=2.9, v_num=0]
# Epoch 14: 100% 127/127 [00:26<00:00,  4.82it/s, loss=2.9, v_num=0]Epoch 14, global step 1800: 'val/CER' was not in top 1
# Epoch 15:  94% 120/127 [00:24<00:01,  4.82it/s, loss=2.82, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 15: 100% 127/127 [00:26<00:00,  4.79it/s, loss=2.82, v_num=0]
# Epoch 15: 100% 127/127 [00:26<00:00,  4.79it/s, loss=2.82, v_num=0]Epoch 15, global step 1920: 'val/CER' was not in top 1
# Epoch 16:  94% 120/127 [00:24<00:01,  4.84it/s, loss=2.77, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 16: 100% 127/127 [00:26<00:00,  4.82it/s, loss=2.77, v_num=0]
# Epoch 16: 100% 127/127 [00:26<00:00,  4.82it/s, loss=2.77, v_num=0]Epoch 16, global step 2040: 'val/CER' was not in top 1
# Epoch 17:  94% 120/127 [00:24<00:01,  4.85it/s, loss=2.61, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 17: 100% 127/127 [00:26<00:00,  4.83it/s, loss=2.61, v_num=0]
# Epoch 17: 100% 127/127 [00:26<00:00,  4.83it/s, loss=2.61, v_num=0]Epoch 17, global step 2160: 'val/CER' was not in top 1
# Epoch 18:  94% 120/127 [00:24<00:01,  4.85it/s, loss=2.51, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 18: 100% 127/127 [00:26<00:00,  4.84it/s, loss=2.51, v_num=0]
# Epoch 18: 100% 127/127 [00:26<00:00,  4.84it/s, loss=2.51, v_num=0]Epoch 18, global step 2280: 'val/CER' reached 99.95570 (best 99.95570), saving model to '/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/epoch=18-step=2280.ckpt' as top 1
# Epoch 19:  94% 120/127 [00:25<00:01,  4.80it/s, loss=2.43, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 19: 100% 127/127 [00:26<00:00,  4.78it/s, loss=2.43, v_num=0]
# Epoch 19: 100% 127/127 [00:26<00:00,  4.78it/s, loss=2.43, v_num=0]Epoch 19, global step 2400: 'val/CER' reached 99.29109 (best 99.29109), saving model to '/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/epoch=19-step=2400.ckpt' as top 1
# Epoch 20:  94% 120/127 [00:24<00:01,  4.84it/s, loss=2.39, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 20: 100% 127/127 [00:26<00:00,  4.81it/s, loss=2.39, v_num=0]
# Epoch 20: 100% 127/127 [00:26<00:00,  4.81it/s, loss=2.39, v_num=0]Epoch 20, global step 2520: 'val/CER' reached 97.67390 (best 97.67390), saving model to '/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/epoch=20-step=2520.ckpt' as top 1
# Epoch 21:  94% 120/127 [00:24<00:01,  4.82it/s, loss=2.32, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 21: 100% 127/127 [00:26<00:00,  4.80it/s, loss=2.32, v_num=0]
# Epoch 21: 100% 127/127 [00:26<00:00,  4.80it/s, loss=2.32, v_num=0]Epoch 21, global step 2640: 'val/CER' was not in top 1
# Epoch 22:  94% 120/127 [00:24<00:01,  4.84it/s, loss=2.25, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 22: 100% 127/127 [00:26<00:00,  4.82it/s, loss=2.25, v_num=0]
# Epoch 22: 100% 127/127 [00:26<00:00,  4.82it/s, loss=2.25, v_num=0]Epoch 22, global step 2760: 'val/CER' reached 95.39211 (best 95.39211), saving model to '/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/epoch=22-step=2760.ckpt' as top 1
# Epoch 23:  94% 120/127 [00:25<00:01,  4.79it/s, loss=2.19, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 23: 100% 127/127 [00:26<00:00,  4.77it/s, loss=2.19, v_num=0]
# Epoch 23: 100% 127/127 [00:26<00:00,  4.77it/s, loss=2.19, v_num=0]Epoch 23, global step 2880: 'val/CER' reached 94.99335 (best 94.99335), saving model to '/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/epoch=23-step=2880.ckpt' as top 1
# Epoch 24:  94% 120/127 [00:24<00:01,  4.84it/s, loss=2.13, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 24: 100% 127/127 [00:26<00:00,  4.84it/s, loss=2.13, v_num=0]
# Epoch 24: 100% 127/127 [00:26<00:00,  4.83it/s, loss=2.13, v_num=0]Epoch 24, global step 3000: 'val/CER' reached 93.19894 (best 93.19894), saving model to '/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/epoch=24-step=3000.ckpt' as top 1
# Epoch 25:  94% 120/127 [00:25<00:01,  4.80it/s, loss=2.09, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 25: 100% 127/127 [00:26<00:00,  4.77it/s, loss=2.09, v_num=0]
# Epoch 25: 100% 127/127 [00:26<00:00,  4.77it/s, loss=2.09, v_num=0]Epoch 25, global step 3120: 'val/CER' reached 89.56580 (best 89.56580), saving model to '/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/epoch=25-step=3120.ckpt' as top 1
# Epoch 26:  94% 120/127 [00:25<00:01,  4.79it/s, loss=2.07, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 26: 100% 127/127 [00:26<00:00,  4.78it/s, loss=2.07, v_num=0]
# Epoch 26: 100% 127/127 [00:26<00:00,  4.78it/s, loss=2.07, v_num=0]Epoch 26, global step 3240: 'val/CER' was not in top 1
# Epoch 27:  94% 120/127 [00:25<00:01,  4.78it/s, loss=2, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 27: 100% 127/127 [00:26<00:00,  4.77it/s, loss=2, v_num=0]
# Epoch 27: 100% 127/127 [00:26<00:00,  4.77it/s, loss=2, v_num=0]Epoch 27, global step 3360: 'val/CER' was not in top 1
# Epoch 28:  94% 120/127 [00:24<00:01,  4.81it/s, loss=1.99, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 28: 100% 127/127 [00:26<00:00,  4.80it/s, loss=1.99, v_num=0]
# Epoch 28: 100% 127/127 [00:26<00:00,  4.80it/s, loss=1.99, v_num=0]Epoch 28, global step 3480: 'val/CER' reached 88.92335 (best 88.92335), saving model to '/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/epoch=28-step=3480.ckpt' as top 1
# Epoch 29:  94% 120/127 [00:25<00:01,  4.79it/s, loss=1.96, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 29: 100% 127/127 [00:26<00:00,  4.78it/s, loss=1.96, v_num=0]
# Epoch 29: 100% 127/127 [00:26<00:00,  4.78it/s, loss=1.96, v_num=0]Epoch 29, global step 3600: 'val/CER' was not in top 1
# Epoch 30:  94% 120/127 [00:24<00:01,  4.83it/s, loss=1.91, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 30: 100% 127/127 [00:26<00:00,  4.80it/s, loss=1.91, v_num=0]
# Epoch 30: 100% 127/127 [00:26<00:00,  4.80it/s, loss=1.91, v_num=0]Epoch 30, global step 3720: 'val/CER' reached 85.88834 (best 85.88834), saving model to '/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/epoch=30-step=3720.ckpt' as top 1
# Epoch 31:  94% 120/127 [00:24<00:01,  4.82it/s, loss=1.87, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 31: 100% 127/127 [00:26<00:00,  4.79it/s, loss=1.87, v_num=0]
# Epoch 31: 100% 127/127 [00:26<00:00,  4.79it/s, loss=1.87, v_num=0]Epoch 31, global step 3840: 'val/CER' reached 83.56225 (best 83.56225), saving model to '/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/epoch=31-step=3840.ckpt' as top 1
# Epoch 32:  94% 120/127 [00:24<00:01,  4.83it/s, loss=1.84, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 32: 100% 127/127 [00:26<00:00,  4.80it/s, loss=1.84, v_num=0]
# Epoch 32: 100% 127/127 [00:26<00:00,  4.80it/s, loss=1.84, v_num=0]Epoch 32, global step 3960: 'val/CER' reached 79.81834 (best 79.81834), saving model to '/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/epoch=32-step=3960.ckpt' as top 1
# Epoch 33:  94% 120/127 [00:24<00:01,  4.82it/s, loss=1.82, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 33: 100% 127/127 [00:26<00:00,  4.79it/s, loss=1.82, v_num=0]
# Epoch 33: 100% 127/127 [00:26<00:00,  4.79it/s, loss=1.82, v_num=0]Epoch 33, global step 4080: 'val/CER' was not in top 1
# Epoch 34:  94% 120/127 [00:25<00:01,  4.79it/s, loss=1.79, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 34: 100% 127/127 [00:26<00:00,  4.77it/s, loss=1.79, v_num=0]
# Epoch 34: 100% 127/127 [00:26<00:00,  4.77it/s, loss=1.79, v_num=0]Epoch 34, global step 4200: 'val/CER' was not in top 1
# Epoch 35:  94% 120/127 [00:25<00:01,  4.80it/s, loss=1.77, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 35: 100% 127/127 [00:26<00:00,  4.77it/s, loss=1.77, v_num=0]
# Epoch 35: 100% 127/127 [00:26<00:00,  4.77it/s, loss=1.77, v_num=0]Epoch 35, global step 4320: 'val/CER' was not in top 1
# Epoch 36:  94% 120/127 [00:24<00:01,  4.80it/s, loss=1.78, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 36: 100% 127/127 [00:26<00:00,  4.78it/s, loss=1.78, v_num=0]
# Epoch 36: 100% 127/127 [00:26<00:00,  4.78it/s, loss=1.78, v_num=0]Epoch 36, global step 4440: 'val/CER' reached 78.88790 (best 78.88790), saving model to '/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/epoch=36-step=4440.ckpt' as top 1
# Epoch 37:  94% 120/127 [00:25<00:01,  4.77it/s, loss=1.77, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 37: 100% 127/127 [00:26<00:00,  4.74it/s, loss=1.77, v_num=0]
# Epoch 37: 100% 127/127 [00:26<00:00,  4.74it/s, loss=1.77, v_num=0]Epoch 37, global step 4560: 'val/CER' was not in top 1
# Epoch 38:  94% 120/127 [00:25<00:01,  4.78it/s, loss=1.75, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 38: 100% 127/127 [00:26<00:00,  4.77it/s, loss=1.75, v_num=0]
# Epoch 38: 100% 127/127 [00:26<00:00,  4.77it/s, loss=1.75, v_num=0]Epoch 38, global step 4680: 'val/CER' was not in top 1
# Epoch 39:  94% 120/127 [00:24<00:01,  4.81it/s, loss=1.75, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 39: 100% 127/127 [00:26<00:00,  4.80it/s, loss=1.75, v_num=0]
# Epoch 39: 100% 127/127 [00:26<00:00,  4.80it/s, loss=1.75, v_num=0]Epoch 39, global step 4800: 'val/CER' was not in top 1
# `Trainer.fit` stopped: `max_epochs=40` reached.
# Epoch 39: 100% 127/127 [00:26<00:00,  4.77it/s, loss=1.75, v_num=0]
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Validation DataLoader 0: 100% 7/7 [00:00<00:00,  8.96it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃  Runningstage.validating  ┃                           ┃
# ┃          metric           ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          val/CER          │     78.88790130615234     │
# │          val/DER          │    0.04430660232901573    │
# │          val/IER          │     77.2485580444336      │
# │          val/SER          │    1.5950376987457275     │
# │         val/loss          │    1.6131603717803955     │
# └───────────────────────────┴───────────────────────────┘
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0:   0% 0/1 [00:00<?, ?it/s]Error executing job with overrides: ['user=single_user', 'model=transformer_ctc', 'dataset.root=/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/data/89335547', 'trainer.accelerator=gpu', 'trainer.devices=1', 'trainer.max_epochs=40']
# Traceback (most recent call last):
#   File "/content/emg2qwerty/emg2qwerty/train.py", line 117, in main
#     test_metrics = trainer.test(module, datamodule)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/trainer.py", line 780, in test
#     return call._call_and_handle_interrupt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/call.py", line 38, in _call_and_handle_interrupt
#     return trainer_fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/trainer.py", line 829, in _test_impl
#     results = self._run(model, ckpt_path=self.ckpt_path)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/trainer.py", line 1098, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/trainer.py", line 1174, in _run_stage
#     return self._run_evaluate()
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/trainer.py", line 1214, in _run_evaluate
#     eval_loop_results = self._evaluation_loop.run()
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/loops/loop.py", line 199, in run
#     self.advance(*args, **kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/loops/dataloader/evaluation_loop.py", line 152, in advance
#     dl_outputs = self.epoch_loop.run(self._data_fetcher, dl_max_batches, kwargs)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/loops/loop.py", line 199, in run
#     self.advance(*args, **kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/loops/epoch/evaluation_epoch_loop.py", line 137, in advance
#     output = self._evaluation_step(**kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/loops/epoch/evaluation_epoch_loop.py", line 234, in _evaluation_step
#     output = self.trainer._call_strategy_hook(hook_name, *kwargs.values())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/trainer.py", line 1480, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/strategies/strategy.py", line 399, in test_step
#     return self.model.test_step(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/emg2qwerty/emg2qwerty/lightning.py", line 795, in test_step
#     return self._step("test", *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/emg2qwerty/emg2qwerty/lightning.py", line 753, in _step
#     emissions = self.forward(inputs)
#                 ^^^^^^^^^^^^^^^^^^^^
#   File "/content/emg2qwerty/emg2qwerty/lightning.py", line 742, in forward
#     return self.model(inputs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/container.py", line 217, in forward
#     input = module(input)
#             ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/emg2qwerty/emg2qwerty/modules.py", line 525, in forward
#     x = self.pos_encoding(x)       # (T, N, d_model)
#         ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/emg2qwerty/emg2qwerty/modules.py", line 472, in forward
#     inputs = inputs + self.pe[: inputs.size(0)]
#              ~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~
# RuntimeError: The size of tensor a (140757) must match the size of tensor b (5000) at non-singleton dimension 0
#
# Set the environment variable HYDRA_FULL_ERROR=1 for a complete stack trace.
# Testing DataLoader 0:   0% 0/1 [00:00<?, ?it/s]
# sys:1: DeprecationWarning: builtin type swigvarlink has no __module__ attribute

# %% [markdown]
# ## Resume after disconnect

# %%
# !cd {REPO} && python -m emg2qwerty.train \
  user="single_user" \
  model={MODEL} \
  dataset.root="{DATA}" \
  hydra.run.dir="{LOGS}/{EXP}" \
  checkpoint="{LOGS}/{EXP}/checkpoints/last.ckpt" \
  trainer.accelerator=gpu trainer.devices=1 \
  trainer.max_epochs=100
# Out:
# [2026-03-13 08:17:12,017][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622679967-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-03-1622764398-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626917264-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622889105-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-03-1622766673-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622861066-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627001995-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622884635-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626915176-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   val:
#   - user: 89335547
#     session: 2021-06-04-1622862148-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   test:
#   - user: 89335547
#     session: 2021-06-02-1622682789-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   root: /content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/data/89335547
# to_tensor:
#   _target_: emg2qwerty.transforms.ToTensor
#   fields:
#   - emg_left
#   - emg_right
# band_rotation:
#   _target_: emg2qwerty.transforms.ForEach
#   transform:
#     _target_: emg2qwerty.transforms.RandomBandRotation
#     offsets:
#     - -1
#     - 0
#     - 1
# temporal_jitter:
#   _target_: emg2qwerty.transforms.TemporalAlignmentJitter
#   max_offset: 120
# logspec:
#   _target_: emg2qwerty.transforms.LogSpectrogram
#   n_fft: 64
#   hop_length: 16
# specaug:
#   _target_: emg2qwerty.transforms.SpecAugment
#   n_time_masks: 3
#   time_mask_param: 25
#   n_freq_masks: 2
#   freq_mask_param: 4
# transforms:
#   train:
#   - ${to_tensor}
#   - ${band_rotation}
#   - ${temporal_jitter}
#   - ${logspec}
#   - ${specaug}
#   val:
#   - ${to_tensor}
#   - ${logspec}
#   test: ${transforms.val}
# module:
#   _target_: emg2qwerty.lightning.TransformerCTCModule
#   in_features: 528
#   mlp_features:
#   - 384
#   d_model: 256
#   nhead: 8
#   num_layers: 4
#   dim_feedforward: 1024
#   dropout: 0.1
# datamodule:
#   _target_: emg2qwerty.lightning.WindowedEMGDataModule
#   window_length: 8000
#   padding:
#   - 1800
#   - 200
# optimizer:
#   _target_: torch.optim.Adam
#   lr: 0.001
# lr_scheduler:
#   scheduler:
#     _target_: pl_bolts.optimizers.lr_scheduler.LinearWarmupCosineAnnealingLR
#     warmup_epochs: 10
#     max_epochs: ${trainer.max_epochs}
#     warmup_start_lr: 1.0e-08
#     eta_min: 1.0e-06
#   interval: epoch
# decoder:
#   _target_: emg2qwerty.decoder.CTCGreedyDecoder
# seed: 1501
# batch_size: 32
# num_workers: 4
# train: true
# checkpoint: /content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/last.ckpt
# monitor_metric: val/CER
# monitor_mode: min
# trainer:
#   accelerator: gpu
#   devices: 1
#   num_nodes: 1
#   max_epochs: 100
#   default_root_dir: ${hydra:runtime.output_dir}
# callbacks:
# - _target_: pytorch_lightning.callbacks.LearningRateMonitor
# - _target_: pytorch_lightning.callbacks.ModelCheckpoint
#   dirpath: ${hydra:runtime.output_dir}/checkpoints
#   monitor: ${monitor_metric}
#   mode: ${monitor_mode}
#   save_last: true
#   verbose: true
#
# Global seed set to 1501
# [2026-03-13 08:17:12,020][__main__][INFO] - Instantiating LightningModule {'_target_': 'emg2qwerty.lightning.TransformerCTCModule', 'in_features': 528, 'mlp_features': [384], 'd_model': 256, 'nhead': 8, 'num_layers': 4, 'dim_feedforward': 1024, 'dropout': 0.1}
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [2026-03-13 08:17:12,107][__main__][INFO] - Loading module from checkpoint /content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/last.ckpt
# [2026-03-13 08:17:12,213][__main__][INFO] - Instantiating LightningDataModule {'_target_': 'emg2qwerty.lightning.WindowedEMGDataModule', 'window_length': 8000, 'padding': [1800, 200]}
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/callbacks/model_checkpoint.py:604: UserWarning: Checkpoint directory /content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints exists and is not empty.
#   rank_zero_warn(f"Checkpoint directory {dirpath} exists and is not empty.")
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.12/dist-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# /usr/local/lib/python3.12/dist-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/matplotlib/_fontconfig_pattern.py:64: PyparsingDeprecationWarning: 'oneOf' deprecated - use 'one_of'
#   prop = Group((name + Suppress("=") + comma_separated(value)) | oneOf(_CONSTANTS))
# /usr/local/lib/python3.12/dist-packages/matplotlib/_fontconfig_pattern.py:85: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   parse = parser.parseString(pattern)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_fontconfig_pattern.py:89: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   parser.resetCache()
# /usr/local/lib/python3.12/dist-packages/pl_bolts/models/self_supervised/amdim/amdim_module.py:34: UnderReviewWarning: The feature generate_power_seq is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   "lr_options": generate_power_seq(LEARNING_RATE_CIFAR, 11),
# /usr/local/lib/python3.12/dist-packages/pl_bolts/models/self_supervised/amdim/amdim_module.py:92: UnderReviewWarning: The feature FeatureMapContrastiveTask is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   contrastive_task: Union[FeatureMapContrastiveTask] = FeatureMapContrastiveTask("01, 02, 11"),
# /usr/local/lib/python3.12/dist-packages/pl_bolts/losses/self_supervised_learning.py:228: UnderReviewWarning: The feature AmdimNCELoss is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   self.nce_loss = AmdimNCELoss(tclip)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:45: PyparsingDeprecationWarning: 'enablePackrat' deprecated - use 'enable_packrat'
#   ParserElement.enablePackrat()
# [2026-03-13 08:17:13,740][matplotlib.style.core][WARNING] - In /usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle: 'parseString' deprecated - use 'parse_string'
# [2026-03-13 08:17:13,740][matplotlib.style.core][WARNING] - In /usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle: 'resetCache' deprecated - use 'reset_cache'
# /usr/local/lib/python3.12/dist-packages/hydra/_internal/instantiate/_instantiate2.py:92: UnderReviewWarning: The feature LinearWarmupCosineAnnealingLR is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   return _target_(*args, **kwargs)
#
#   | Name     | Type       | Params
# ----------------------------------------
# 0 | model    | Sequential | 3.8 M
# 1 | ctc_loss | CTCLoss    | 0
# 2 | metrics  | ModuleDict | 0
# ----------------------------------------
# 3.8 M     Trainable params
# 0         Non-trainable params
# 3.8 M     Total params
# 15.151    Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]/usr/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7621) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# Epoch 0:  94% 120/127 [00:27<00:01,  4.32it/s, loss=1.77, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 0: 100% 127/127 [00:29<00:00,  4.33it/s, loss=1.77, v_num=1]
# Epoch 0: 100% 127/127 [00:29<00:00,  4.33it/s, loss=1.77, v_num=1]Epoch 0, global step 120: 'val/CER' reached 78.75498 (best 78.75498), saving model to '/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/epoch=0-step=120.ckpt' as top 1
# Epoch 1:  94% 120/127 [00:25<00:01,  4.72it/s, loss=1.78, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 1: 100% 127/127 [00:26<00:00,  4.72it/s, loss=1.78, v_num=1]
# Epoch 1: 100% 127/127 [00:26<00:00,  4.72it/s, loss=1.78, v_num=1]Epoch 1, global step 240: 'val/CER' was not in top 1
# Epoch 2:  94% 120/127 [00:26<00:01,  4.53it/s, loss=1.78, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 2: 100% 127/127 [00:28<00:00,  4.51it/s, loss=1.78, v_num=1]
# Epoch 2: 100% 127/127 [00:28<00:00,  4.51it/s, loss=1.78, v_num=1]Epoch 2, global step 360: 'val/CER' reached 75.32122 (best 75.32122), saving model to '/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/epoch=2-step=360.ckpt' as top 1
# Epoch 3:  94% 120/127 [00:25<00:01,  4.65it/s, loss=1.76, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 3: 100% 127/127 [00:27<00:00,  4.63it/s, loss=1.76, v_num=1]
# Epoch 3: 100% 127/127 [00:27<00:00,  4.63it/s, loss=1.76, v_num=1]Epoch 3, global step 480: 'val/CER' was not in top 1
# Epoch 4:  94% 120/127 [00:24<00:01,  4.80it/s, loss=1.8, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 4: 100% 127/127 [00:26<00:00,  4.79it/s, loss=1.8, v_num=1]
# Epoch 4: 100% 127/127 [00:26<00:00,  4.79it/s, loss=1.8, v_num=1]Epoch 4, global step 600: 'val/CER' was not in top 1
# Epoch 5:  94% 120/127 [00:24<00:01,  4.80it/s, loss=1.72, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 5: 100% 127/127 [00:26<00:00,  4.77it/s, loss=1.72, v_num=1]
# Epoch 5: 100% 127/127 [00:26<00:00,  4.77it/s, loss=1.72, v_num=1]Epoch 5, global step 720: 'val/CER' reached 70.18166 (best 70.18166), saving model to '/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/epoch=5-step=720.ckpt' as top 1
# Epoch 6:  94% 120/127 [00:25<00:01,  4.75it/s, loss=1.67, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 6: 100% 127/127 [00:26<00:00,  4.73it/s, loss=1.67, v_num=1]
# Epoch 6: 100% 127/127 [00:26<00:00,  4.73it/s, loss=1.67, v_num=1]Epoch 6, global step 840: 'val/CER' reached 64.20026 (best 64.20026), saving model to '/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/epoch=6-step=840.ckpt' as top 1
# Epoch 7:  94% 120/127 [00:25<00:01,  4.75it/s, loss=1.65, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 7: 100% 127/127 [00:26<00:00,  4.75it/s, loss=1.65, v_num=1]
# Epoch 7: 100% 127/127 [00:26<00:00,  4.75it/s, loss=1.65, v_num=1]Epoch 7, global step 960: 'val/CER' reached 59.79176 (best 59.79176), saving model to '/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/epoch=7-step=960.ckpt' as top 1
# Epoch 8:  94% 120/127 [00:25<00:01,  4.78it/s, loss=1.68, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 8: 100% 127/127 [00:26<00:00,  4.75it/s, loss=1.68, v_num=1]
# Epoch 8: 100% 127/127 [00:26<00:00,  4.75it/s, loss=1.68, v_num=1]Epoch 8, global step 1080: 'val/CER' was not in top 1
# Epoch 9:  94% 120/127 [00:26<00:01,  4.57it/s, loss=1.56, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 9: 100% 127/127 [00:27<00:00,  4.56it/s, loss=1.56, v_num=1]
# Epoch 9: 100% 127/127 [00:27<00:00,  4.56it/s, loss=1.56, v_num=1]Epoch 9, global step 1200: 'val/CER' reached 47.34160 (best 47.34160), saving model to '/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/epoch=9-step=1200.ckpt' as top 1
# Epoch 10:  94% 120/127 [00:25<00:01,  4.72it/s, loss=1.52, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 10: 100% 127/127 [00:27<00:00,  4.70it/s, loss=1.52, v_num=1]
# Epoch 10: 100% 127/127 [00:27<00:00,  4.70it/s, loss=1.52, v_num=1]Epoch 10, global step 1320: 'val/CER' was not in top 1
# Epoch 11:  94% 120/127 [00:24<00:01,  4.80it/s, loss=1.53, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 11: 100% 127/127 [00:26<00:00,  4.78it/s, loss=1.53, v_num=1]
# Epoch 11: 100% 127/127 [00:26<00:00,  4.78it/s, loss=1.53, v_num=1]Epoch 11, global step 1440: 'val/CER' reached 43.79708 (best 43.79708), saving model to '/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/epoch=11-step=1440.ckpt' as top 1
# Epoch 12:  94% 120/127 [00:25<00:01,  4.77it/s, loss=1.41, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 12: 100% 127/127 [00:26<00:00,  4.75it/s, loss=1.41, v_num=1]
# Epoch 12: 100% 127/127 [00:26<00:00,  4.75it/s, loss=1.41, v_num=1]Epoch 12, global step 1560: 'val/CER' reached 40.29686 (best 40.29686), saving model to '/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/epoch=12-step=1560.ckpt' as top 1
# Epoch 13:  94% 120/127 [00:25<00:01,  4.77it/s, loss=1.42, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 13: 100% 127/127 [00:26<00:00,  4.74it/s, loss=1.42, v_num=1]
# Epoch 13: 100% 127/127 [00:26<00:00,  4.74it/s, loss=1.42, v_num=1]Epoch 13, global step 1680: 'val/CER' reached 40.11963 (best 40.11963), saving model to '/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/epoch=13-step=1680.ckpt' as top 1
# Epoch 14:  94% 120/127 [00:25<00:01,  4.78it/s, loss=1.38, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 14: 100% 127/127 [00:26<00:00,  4.77it/s, loss=1.38, v_num=1]
# Epoch 14: 100% 127/127 [00:26<00:00,  4.77it/s, loss=1.38, v_num=1]Epoch 14, global step 1800: 'val/CER' reached 40.07532 (best 40.07532), saving model to '/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/epoch=14-step=1800.ckpt' as top 1
# Epoch 15:  94% 120/127 [00:25<00:01,  4.80it/s, loss=1.35, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 15: 100% 127/127 [00:26<00:00,  4.78it/s, loss=1.35, v_num=1]
# Epoch 15: 100% 127/127 [00:26<00:00,  4.78it/s, loss=1.35, v_num=1]Epoch 15, global step 1920: 'val/CER' reached 39.29996 (best 39.29996), saving model to '/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/epoch=15-step=1920.ckpt' as top 1
# Epoch 16:  94% 120/127 [00:25<00:01,  4.77it/s, loss=1.35, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 16: 100% 127/127 [00:26<00:00,  4.74it/s, loss=1.35, v_num=1]
# Epoch 16: 100% 127/127 [00:26<00:00,  4.74it/s, loss=1.35, v_num=1]Epoch 16, global step 2040: 'val/CER' reached 37.70492 (best 37.70492), saving model to '/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/epoch=16-step=2040.ckpt' as top 1
# Epoch 17:  94% 120/127 [00:25<00:01,  4.77it/s, loss=1.3, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 17: 100% 127/127 [00:26<00:00,  4.75it/s, loss=1.3, v_num=1]
# Epoch 17: 100% 127/127 [00:26<00:00,  4.75it/s, loss=1.3, v_num=1]Epoch 17, global step 2160: 'val/CER' reached 35.77758 (best 35.77758), saving model to '/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/epoch=17-step=2160.ckpt' as top 1
# Epoch 18:  94% 120/127 [00:25<00:01,  4.77it/s, loss=1.31, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 18: 100% 127/127 [00:26<00:00,  4.75it/s, loss=1.31, v_num=1]
# Epoch 18: 100% 127/127 [00:26<00:00,  4.75it/s, loss=1.31, v_num=1]Epoch 18, global step 2280: 'val/CER' reached 35.02437 (best 35.02437), saving model to '/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/epoch=18-step=2280.ckpt' as top 1
# Epoch 19:  94% 120/127 [00:25<00:01,  4.78it/s, loss=1.3, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 19: 100% 127/127 [00:26<00:00,  4.76it/s, loss=1.3, v_num=1]
# Epoch 19: 100% 127/127 [00:26<00:00,  4.76it/s, loss=1.3, v_num=1]Epoch 19, global step 2400: 'val/CER' was not in top 1
# Epoch 20:  94% 120/127 [00:25<00:01,  4.74it/s, loss=1.25, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 20: 100% 127/127 [00:26<00:00,  4.73it/s, loss=1.25, v_num=1]
# Epoch 20: 100% 127/127 [00:26<00:00,  4.73it/s, loss=1.25, v_num=1]Epoch 20, global step 2520: 'val/CER' reached 33.11919 (best 33.11919), saving model to '/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/epoch=20-step=2520.ckpt' as top 1
# Epoch 21:  94% 120/127 [00:25<00:01,  4.73it/s, loss=1.27, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 21: 100% 127/127 [00:26<00:00,  4.71it/s, loss=1.27, v_num=1]
# Epoch 21: 100% 127/127 [00:26<00:00,  4.71it/s, loss=1.27, v_num=1]Epoch 21, global step 2640: 'val/CER' was not in top 1
# Epoch 22:  94% 120/127 [00:25<00:01,  4.78it/s, loss=1.27, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 22: 100% 127/127 [00:26<00:00,  4.76it/s, loss=1.27, v_num=1]
# Epoch 22: 100% 127/127 [00:26<00:00,  4.76it/s, loss=1.27, v_num=1]Epoch 22, global step 2760: 'val/CER' was not in top 1
# Epoch 23:  94% 120/127 [00:25<00:01,  4.79it/s, loss=1.23, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 23: 100% 127/127 [00:26<00:00,  4.76it/s, loss=1.23, v_num=1]
# Epoch 23: 100% 127/127 [00:26<00:00,  4.76it/s, loss=1.23, v_num=1]Epoch 23, global step 2880: 'val/CER' was not in top 1
# Epoch 24:  94% 120/127 [00:25<00:01,  4.78it/s, loss=1.15, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 24: 100% 127/127 [00:26<00:00,  4.76it/s, loss=1.15, v_num=1]
# Epoch 24: 100% 127/127 [00:26<00:00,  4.76it/s, loss=1.15, v_num=1]Epoch 24, global step 3000: 'val/CER' reached 30.52725 (best 30.52725), saving model to '/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/epoch=24-step=3000.ckpt' as top 1
# Epoch 25:  94% 120/127 [00:25<00:01,  4.73it/s, loss=1.19, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 25: 100% 127/127 [00:26<00:00,  4.72it/s, loss=1.19, v_num=1]
# Epoch 25: 100% 127/127 [00:26<00:00,  4.72it/s, loss=1.19, v_num=1]Epoch 25, global step 3120: 'val/CER' was not in top 1
# Epoch 26:  94% 120/127 [00:25<00:01,  4.77it/s, loss=1.18, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 26: 100% 127/127 [00:26<00:00,  4.74it/s, loss=1.18, v_num=1]
# Epoch 26: 100% 127/127 [00:26<00:00,  4.74it/s, loss=1.18, v_num=1]Epoch 26, global step 3240: 'val/CER' was not in top 1
# Epoch 27:  94% 120/127 [00:25<00:01,  4.77it/s, loss=1.17, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 27: 100% 127/127 [00:26<00:00,  4.74it/s, loss=1.17, v_num=1]
# Epoch 27: 100% 127/127 [00:26<00:00,  4.74it/s, loss=1.17, v_num=1]Epoch 27, global step 3360: 'val/CER' was not in top 1
# Epoch 28:  94% 120/127 [00:25<00:01,  4.77it/s, loss=1.17, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 28: 100% 127/127 [00:26<00:00,  4.74it/s, loss=1.17, v_num=1]
# Epoch 28: 100% 127/127 [00:26<00:00,  4.74it/s, loss=1.17, v_num=1]Epoch 28, global step 3480: 'val/CER' was not in top 1
# Epoch 29:  94% 120/127 [00:25<00:01,  4.78it/s, loss=1.09, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 29: 100% 127/127 [00:26<00:00,  4.77it/s, loss=1.09, v_num=1]
# Epoch 29: 100% 127/127 [00:26<00:00,  4.76it/s, loss=1.09, v_num=1]Epoch 29, global step 3600: 'val/CER' was not in top 1
# Epoch 30:  94% 120/127 [00:25<00:01,  4.80it/s, loss=1.13, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 30: 100% 127/127 [00:26<00:00,  4.77it/s, loss=1.13, v_num=1]
# Epoch 30: 100% 127/127 [00:26<00:00,  4.77it/s, loss=1.13, v_num=1]Epoch 30, global step 3720: 'val/CER' was not in top 1
# Epoch 31:  94% 120/127 [00:25<00:01,  4.78it/s, loss=1.06, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 31: 100% 127/127 [00:26<00:00,  4.76it/s, loss=1.06, v_num=1]
# Epoch 31: 100% 127/127 [00:26<00:00,  4.76it/s, loss=1.06, v_num=1]Epoch 31, global step 3840: 'val/CER' reached 28.13469 (best 28.13469), saving model to '/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/epoch=31-step=3840.ckpt' as top 1
# Epoch 32:  94% 120/127 [00:25<00:01,  4.79it/s, loss=1.09, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 32: 100% 127/127 [00:26<00:00,  4.78it/s, loss=1.09, v_num=1]
# Epoch 32: 100% 127/127 [00:26<00:00,  4.78it/s, loss=1.09, v_num=1]Epoch 32, global step 3960: 'val/CER' reached 28.09039 (best 28.09039), saving model to '/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/epoch=32-step=3960.ckpt' as top 1
# Epoch 33:  94% 120/127 [00:25<00:01,  4.79it/s, loss=1.04, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 33: 100% 127/127 [00:26<00:00,  4.77it/s, loss=1.04, v_num=1]
# Epoch 33: 100% 127/127 [00:26<00:00,  4.77it/s, loss=1.04, v_num=1]Epoch 33, global step 4080: 'val/CER' was not in top 1
# Epoch 34:  94% 120/127 [00:25<00:01,  4.77it/s, loss=1.12, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 34: 100% 127/127 [00:26<00:00,  4.75it/s, loss=1.12, v_num=1]
# Epoch 34: 100% 127/127 [00:26<00:00,  4.75it/s, loss=1.12, v_num=1]Epoch 34, global step 4200: 'val/CER' was not in top 1
# Epoch 35:  94% 120/127 [00:25<00:01,  4.74it/s, loss=1.06, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 35: 100% 127/127 [00:26<00:00,  4.72it/s, loss=1.06, v_num=1]
# Epoch 35: 100% 127/127 [00:26<00:00,  4.72it/s, loss=1.06, v_num=1]Epoch 35, global step 4320: 'val/CER' reached 27.09349 (best 27.09349), saving model to '/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/epoch=35-step=4320.ckpt' as top 1
# Epoch 36:  94% 120/127 [00:25<00:01,  4.73it/s, loss=1.01, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 36: 100% 127/127 [00:26<00:00,  4.72it/s, loss=1.01, v_num=1]
# Epoch 36: 100% 127/127 [00:26<00:00,  4.72it/s, loss=1.01, v_num=1]Epoch 36, global step 4440: 'val/CER' was not in top 1
# Epoch 37:  94% 120/127 [00:24<00:01,  4.82it/s, loss=1.03, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 37: 100% 127/127 [00:26<00:00,  4.79it/s, loss=1.03, v_num=1]
# Epoch 37: 100% 127/127 [00:26<00:00,  4.79it/s, loss=1.03, v_num=1]Epoch 37, global step 4560: 'val/CER' was not in top 1
# Epoch 38:  94% 120/127 [00:24<00:01,  4.81it/s, loss=0.993, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 38: 100% 127/127 [00:26<00:00,  4.79it/s, loss=0.993, v_num=1]
# Epoch 38: 100% 127/127 [00:26<00:00,  4.79it/s, loss=0.993, v_num=1]Epoch 38, global step 4680: 'val/CER' was not in top 1
# Epoch 39:  94% 120/127 [00:25<00:01,  4.71it/s, loss=1.01, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 39: 100% 127/127 [00:27<00:00,  4.69it/s, loss=1.01, v_num=1]
# Epoch 39: 100% 127/127 [00:27<00:00,  4.69it/s, loss=1.01, v_num=1]Epoch 39, global step 4800: 'val/CER' was not in top 1
# Epoch 40:  94% 120/127 [00:25<00:01,  4.71it/s, loss=0.98, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 40: 100% 127/127 [00:27<00:00,  4.70it/s, loss=0.98, v_num=1]
# Epoch 40: 100% 127/127 [00:27<00:00,  4.70it/s, loss=0.98, v_num=1]Epoch 40, global step 4920: 'val/CER' reached 25.89721 (best 25.89721), saving model to '/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/epoch=40-step=4920.ckpt' as top 1
# Epoch 41:  94% 120/127 [00:25<00:01,  4.69it/s, loss=0.941, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 41: 100% 127/127 [00:27<00:00,  4.68it/s, loss=0.941, v_num=1]
# Epoch 41: 100% 127/127 [00:27<00:00,  4.68it/s, loss=0.941, v_num=1]Epoch 41, global step 5040: 'val/CER' reached 24.21356 (best 24.21356), saving model to '/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/epoch=41-step=5040.ckpt' as top 1
# Epoch 42:  94% 120/127 [00:25<00:01,  4.80it/s, loss=0.96, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 42: 100% 127/127 [00:26<00:00,  4.78it/s, loss=0.96, v_num=1]
# Epoch 42: 100% 127/127 [00:26<00:00,  4.78it/s, loss=0.96, v_num=1]Epoch 42, global step 5160: 'val/CER' was not in top 1
# Epoch 43:  94% 120/127 [00:25<00:01,  4.79it/s, loss=0.948, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 43: 100% 127/127 [00:26<00:00,  4.78it/s, loss=0.948, v_num=1]
# Epoch 43: 100% 127/127 [00:26<00:00,  4.77it/s, loss=0.948, v_num=1]Epoch 43, global step 5280: 'val/CER' was not in top 1
# Epoch 44:  94% 120/127 [00:25<00:01,  4.78it/s, loss=0.908, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 44: 100% 127/127 [00:26<00:00,  4.75it/s, loss=0.908, v_num=1]
# Epoch 44: 100% 127/127 [00:26<00:00,  4.75it/s, loss=0.908, v_num=1]Epoch 44, global step 5400: 'val/CER' was not in top 1
# Epoch 45:  94% 120/127 [00:25<00:01,  4.73it/s, loss=0.895, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 45: 100% 127/127 [00:26<00:00,  4.70it/s, loss=0.895, v_num=1]
# Epoch 45: 100% 127/127 [00:26<00:00,  4.70it/s, loss=0.895, v_num=1]Epoch 45, global step 5520: 'val/CER' was not in top 1
# Epoch 46:  94% 120/127 [00:25<00:01,  4.73it/s, loss=0.88, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 46: 100% 127/127 [00:27<00:00,  4.70it/s, loss=0.88, v_num=1]
# Epoch 46: 100% 127/127 [00:27<00:00,  4.70it/s, loss=0.88, v_num=1]Epoch 46, global step 5640: 'val/CER' was not in top 1
# Epoch 47:  94% 120/127 [00:25<00:01,  4.75it/s, loss=0.896, v_num=1]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 47: 100% 127/127 [00:26<00:00,  4.72it/s, loss=0.896, v_num=1]
# Epoch 47: 100% 127/127 [00:26<00:00,  4.72it/s, loss=0.896, v_num=1]Epoch 47, global step 5760: 'val/CER' reached 24.03633 (best 24.03633), saving model to '/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/epoch=47-step=5760.ckpt' as top 1
# Epoch 48:  16% 20/127 [00:04<00:24,  4.35it/s, loss=0.853, v_num=1]/usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/call.py:48: UserWarning: Detected KeyboardInterrupt, attempting graceful shutdown...
#   rank_zero_warn("Detected KeyboardInterrupt, attempting graceful shutdown...")
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Validation DataLoader 0: 100% 7/7 [00:00<00:00,  9.73it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃  Runningstage.validating  ┃                           ┃
# ┃          metric           ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          val/CER          │    24.036331176757812     │
# │          val/DER          │    3.5223748683929443     │
# │          val/IER          │     8.307487487792969     │
# │          val/SER          │     12.20646858215332     │
# │         val/loss          │    0.7271084189414978     │
# └───────────────────────────┴───────────────────────────┘
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0:   0% 0/1 [00:00<?, ?it/s]Error executing job with overrides: ['user=single_user', 'model=transformer_ctc', 'dataset.root=/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/data/89335547', 'checkpoint=/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/last.ckpt', 'trainer.accelerator=gpu', 'trainer.devices=1', 'trainer.max_epochs=100']
# Traceback (most recent call last):
#   File "/content/emg2qwerty/emg2qwerty/train.py", line 117, in main
#     test_metrics = trainer.test(module, datamodule)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/trainer.py", line 780, in test
#     return call._call_and_handle_interrupt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/call.py", line 38, in _call_and_handle_interrupt
#     return trainer_fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/trainer.py", line 829, in _test_impl
#     results = self._run(model, ckpt_path=self.ckpt_path)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/trainer.py", line 1098, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/trainer.py", line 1174, in _run_stage
#     return self._run_evaluate()
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/trainer.py", line 1214, in _run_evaluate
#     eval_loop_results = self._evaluation_loop.run()
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/loops/loop.py", line 199, in run
#     self.advance(*args, **kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/loops/dataloader/evaluation_loop.py", line 152, in advance
#     dl_outputs = self.epoch_loop.run(self._data_fetcher, dl_max_batches, kwargs)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/loops/loop.py", line 199, in run
#     self.advance(*args, **kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/loops/epoch/evaluation_epoch_loop.py", line 137, in advance
#     output = self._evaluation_step(**kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/loops/epoch/evaluation_epoch_loop.py", line 234, in _evaluation_step
#     output = self.trainer._call_strategy_hook(hook_name, *kwargs.values())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/trainer.py", line 1480, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/strategies/strategy.py", line 399, in test_step
#     return self.model.test_step(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/emg2qwerty/emg2qwerty/lightning.py", line 795, in test_step
#     return self._step("test", *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/emg2qwerty/emg2qwerty/lightning.py", line 753, in _step
#     emissions = self.forward(inputs)
#                 ^^^^^^^^^^^^^^^^^^^^
#   File "/content/emg2qwerty/emg2qwerty/lightning.py", line 742, in forward
#     return self.model(inputs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/container.py", line 217, in forward
#     input = module(input)
#             ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/emg2qwerty/emg2qwerty/modules.py", line 525, in forward
#     x = self.pos_encoding(x)       # (T, N, d_model)
#         ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/emg2qwerty/emg2qwerty/modules.py", line 472, in forward
#     inputs = inputs + self.pe[: inputs.size(0)]
#              ~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~
# RuntimeError: The size of tensor a (140757) must match the size of tensor b (5000) at non-singleton dimension 0
#
# Set the environment variable HYDRA_FULL_ERROR=1 for a complete stack trace.
# Epoch 48:  16% 20/127 [00:20<01:52,  1.05s/it, loss=0.853, v_num=1]
# Testing DataLoader 0:   0% 0/1 [00:00<?, ?it/s]
# sys:1: DeprecationWarning: builtin type swigvarlink has no __module__ attribute

# %% [markdown]
# ## Test

# %%
# !cd {REPO} && python -m emg2qwerty.train \
  user="single_user" \
  model={MODEL} \
  dataset.root="{DATA}" \
  hydra.run.dir="{LOGS}/{EXP}" \
  checkpoint="{LOGS}/{EXP}/checkpoints/last-v1.ckpt" \
  train=false trainer.accelerator=gpu \
  decoder=ctc_greedy
# Out:
# [2026-03-13 08:41:25,133][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622679967-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-03-1622764398-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626917264-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622889105-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-03-1622766673-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622861066-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627001995-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622884635-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626915176-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   val:
#   - user: 89335547
#     session: 2021-06-04-1622862148-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   test:
#   - user: 89335547
#     session: 2021-06-02-1622682789-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   root: /content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/data/89335547
# to_tensor:
#   _target_: emg2qwerty.transforms.ToTensor
#   fields:
#   - emg_left
#   - emg_right
# band_rotation:
#   _target_: emg2qwerty.transforms.ForEach
#   transform:
#     _target_: emg2qwerty.transforms.RandomBandRotation
#     offsets:
#     - -1
#     - 0
#     - 1
# temporal_jitter:
#   _target_: emg2qwerty.transforms.TemporalAlignmentJitter
#   max_offset: 120
# logspec:
#   _target_: emg2qwerty.transforms.LogSpectrogram
#   n_fft: 64
#   hop_length: 16
# specaug:
#   _target_: emg2qwerty.transforms.SpecAugment
#   n_time_masks: 3
#   time_mask_param: 25
#   n_freq_masks: 2
#   freq_mask_param: 4
# transforms:
#   train:
#   - ${to_tensor}
#   - ${band_rotation}
#   - ${temporal_jitter}
#   - ${logspec}
#   - ${specaug}
#   val:
#   - ${to_tensor}
#   - ${logspec}
#   test: ${transforms.val}
# module:
#   _target_: emg2qwerty.lightning.TransformerCTCModule
#   in_features: 528
#   mlp_features:
#   - 384
#   d_model: 256
#   nhead: 8
#   num_layers: 4
#   dim_feedforward: 1024
#   dropout: 0.1
# datamodule:
#   _target_: emg2qwerty.lightning.WindowedEMGDataModule
#   window_length: 8000
#   padding:
#   - 1800
#   - 200
# optimizer:
#   _target_: torch.optim.Adam
#   lr: 0.001
# lr_scheduler:
#   scheduler:
#     _target_: pl_bolts.optimizers.lr_scheduler.LinearWarmupCosineAnnealingLR
#     warmup_epochs: 10
#     max_epochs: ${trainer.max_epochs}
#     warmup_start_lr: 1.0e-08
#     eta_min: 1.0e-06
#   interval: epoch
# decoder:
#   _target_: emg2qwerty.decoder.CTCGreedyDecoder
# seed: 1501
# batch_size: 32
# num_workers: 4
# train: false
# checkpoint: /content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/last-v1.ckpt
# monitor_metric: val/CER
# monitor_mode: min
# trainer:
#   accelerator: gpu
#   devices: 1
#   num_nodes: 1
#   max_epochs: 150
#   default_root_dir: ${hydra:runtime.output_dir}
# callbacks:
# - _target_: pytorch_lightning.callbacks.LearningRateMonitor
# - _target_: pytorch_lightning.callbacks.ModelCheckpoint
#   dirpath: ${hydra:runtime.output_dir}/checkpoints
#   monitor: ${monitor_metric}
#   mode: ${monitor_mode}
#   save_last: true
#   verbose: true
#
# Global seed set to 1501
# [2026-03-13 08:41:25,136][__main__][INFO] - Instantiating LightningModule {'_target_': 'emg2qwerty.lightning.TransformerCTCModule', 'in_features': 528, 'mlp_features': [384], 'd_model': 256, 'nhead': 8, 'num_layers': 4, 'dim_feedforward': 1024, 'dropout': 0.1}
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [2026-03-13 08:41:25,222][__main__][INFO] - Loading module from checkpoint /content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/last-v1.ckpt
# [2026-03-13 08:41:25,342][__main__][INFO] - Instantiating LightningDataModule {'_target_': 'emg2qwerty.lightning.WindowedEMGDataModule', 'window_length': 8000, 'padding': [1800, 200]}
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Validation DataLoader 0: 100% 7/7 [00:00<00:00,  8.13it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃  Runningstage.validating  ┃                           ┃
# ┃          metric           ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          val/CER          │    24.036331176757812     │
# │          val/DER          │    3.5223748683929443     │
# │          val/IER          │     8.307487487792969     │
# │          val/SER          │     12.20646858215332     │
# │         val/loss          │    0.7271084189414978     │
# └───────────────────────────┴───────────────────────────┘
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0:   0% 0/1 [00:00<?, ?it/s]Error executing job with overrides: ['user=single_user', 'model=transformer_ctc', 'dataset.root=/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/data/89335547', 'checkpoint=/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs/transformer_run1/checkpoints/last-v1.ckpt', 'train=false', 'trainer.accelerator=gpu', 'decoder=ctc_greedy']
# Traceback (most recent call last):
#   File "/content/emg2qwerty/emg2qwerty/train.py", line 117, in main
#     test_metrics = trainer.test(module, datamodule)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/trainer.py", line 780, in test
#     return call._call_and_handle_interrupt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/call.py", line 38, in _call_and_handle_interrupt
#     return trainer_fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/trainer.py", line 829, in _test_impl
#     results = self._run(model, ckpt_path=self.ckpt_path)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/trainer.py", line 1098, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/trainer.py", line 1174, in _run_stage
#     return self._run_evaluate()
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/trainer.py", line 1214, in _run_evaluate
#     eval_loop_results = self._evaluation_loop.run()
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/loops/loop.py", line 199, in run
#     self.advance(*args, **kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/loops/dataloader/evaluation_loop.py", line 152, in advance
#     dl_outputs = self.epoch_loop.run(self._data_fetcher, dl_max_batches, kwargs)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/loops/loop.py", line 199, in run
#     self.advance(*args, **kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/loops/epoch/evaluation_epoch_loop.py", line 137, in advance
#     output = self._evaluation_step(**kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/loops/epoch/evaluation_epoch_loop.py", line 234, in _evaluation_step
#     output = self.trainer._call_strategy_hook(hook_name, *kwargs.values())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/trainer.py", line 1480, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pytorch_lightning/strategies/strategy.py", line 399, in test_step
#     return self.model.test_step(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/emg2qwerty/emg2qwerty/lightning.py", line 795, in test_step
#     return self._step("test", *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/emg2qwerty/emg2qwerty/lightning.py", line 753, in _step
#     emissions = self.forward(inputs)
#                 ^^^^^^^^^^^^^^^^^^^^
#   File "/content/emg2qwerty/emg2qwerty/lightning.py", line 742, in forward
#     return self.model(inputs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/container.py", line 217, in forward
#     input = module(input)
#             ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/emg2qwerty/emg2qwerty/modules.py", line 525, in forward
#     x = self.pos_encoding(x)       # (T, N, d_model)
#         ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/emg2qwerty/emg2qwerty/modules.py", line 472, in forward
#     inputs = inputs + self.pe[: inputs.size(0)]
#              ~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~
# RuntimeError: The size of tensor a (140757) must match the size of tensor b (5000) at non-singleton dimension 0
#
# Set the environment variable HYDRA_FULL_ERROR=1 for a complete stack trace.
# Testing DataLoader 0:   0% 0/1 [00:00<?, ?it/s]

# %%
# !jupyter nbconvert --to pdf 04_Transformer.ipynb
# Out:
# [NbConvertApp] Converting notebook 04_Transformer.ipynb to pdf
# /opt/anaconda3/envs/ece-c147a-py311/lib/python3.11/site-packages/nbconvert/utils/pandoc.py:51: RuntimeWarning: You are using an unsupported version of pandoc (3.8.3).
# Your version must be at least (1.12.1) but less than (3.0.0).
# Refer to https://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# [NbConvertApp] Writing 135986 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', 'notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 88424 bytes to 04_Transformer.pdf
