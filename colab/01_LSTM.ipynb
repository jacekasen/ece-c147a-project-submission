# %%
# !nvidia-smi
# Out:
# Fri Mar 13 05:01:12 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-80GB          Off |   00000000:00:05.0 Off |                    0 |
# | N/A   34C    P0             53W /  400W |       0MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/jacekasen/ece-c147a-project.git /content/emg2qwerty
# !cd /content/emg2qwerty && pip install -r requirements.txt -q && pip install -e . -q
# Out:
# Cloning into '/content/emg2qwerty'...
# remote: Enumerating objects: 158, done.
# remote: Counting objects: 100% (158/158), done.
# remote: Compressing objects: 100% (119/119), done.
# remote: Total 158 (delta 40), reused 151 (delta 33), pack-reused 0 (from 0)
# Receiving objects: 100% (158/158), 33.52 MiB | 13.06 MiB/s, done.
# Resolving deltas: 100% (40/40), done.
# ...
# Error downloading object: models/generic.ckpt (338afa5): Smudge error: Error downloading models/generic.ckpt (338afa55f2ad5dd23abe3900e8047068bf8ee9893e75b54e1c6e6ab91c0d1a81): [338afa55f2ad5dd23abe3900e8047068bf8ee9893e75b54e1c6e6ab91c0d1a81] Object does not exist on the server: [404] Object does not exist on the server
#
# Errors logged to /content/emg2qwerty/.git/lfs/logs/20260313T050208.003469195.log
# Use `git lfs logs last` to view the log.
# error: external filter 'git-lfs filter-process' failed
# fatal: models/generic.ckpt: smudge filter lfs failed
# ...
# You can inspect what was checked out with 'git status'
# ...

# %%
# --- CONFIG ---
DATA   = "/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/data/89335547"
LOGS   = "/content/drive/MyDrive/17-Winter-2026/ECE-C147A/Project/logs"
REPO   = "/content/emg2qwerty"

MODEL  = "lstm_ctc"   # tds_conv_ctc | lstm_ctc
EXP    = "lstm_ctc_run1"       # change per experiment (e.g. lstm_ctc_run1)

# %% [markdown]
# ## Train

# %%
# !cd {REPO} && python -m emg2qwerty.train \
  user="single_user" \
  model={MODEL} \
  dataset.root="{DATA}" \
  hydra.run.dir="{LOGS}/{EXP}" \
  trainer.accelerator=gpu trainer.devices=1 \
  trainer.max_epochs=40
# Out:
# [2026-03-13 05:06:10,035][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %% [markdown]
# ## Resume after disconnect

# %%
# !cd {REPO} && python -m emg2qwerty.train \
  user="single_user" \
  model={MODEL} \
  dataset.root="{DATA}" \
  hydra.run.dir="{LOGS}/{EXP}" \
  checkpoint="{LOGS}/{EXP}/checkpoints/last.ckpt" \
  trainer.accelerator=gpu trainer.devices=1 \
  trainer.max_epochs=40
# Out:
# [2026-03-13 05:26:31,408][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %% [markdown]
# ## Test

# %%
# !cd {REPO} && python -m emg2qwerty.train \
  user="single_user" \
  model={MODEL} \
  dataset.root="{DATA}" \
  hydra.run.dir="{LOGS}/{EXP}" \
  checkpoint="{LOGS}/{EXP}/checkpoints/last.ckpt" \
  train=false trainer.accelerator=gpu \
  decoder=ctc_greedy
# Out:
# [2026-03-13 05:26:47,451][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# !jupyter nbconvert --to pdf 01_LSTM.ipynb
# Out:
# [NbConvertApp] Converting notebook 01_LSTM.ipynb to pdf
# /opt/anaconda3/envs/ece-c147a-py311/lib/python3.11/site-packages/nbconvert/utils/pandoc.py:51: RuntimeWarning: You are using an unsupported version of pandoc (3.8.3).
# Your version must be at least (1.12.1) but less than (3.0.0).
# Refer to https://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# [NbConvertApp] Writing 85881 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', 'notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 68184 bytes to 01_LSTM.pdf
